# %% [markdown]
# Project Link: https://github.com/mubtasimahasan/disaster-image-classification-pytorch
#
# Data Link: https://drive.google.com/drive/folders/1VvkBRIYW6oD31K3gkPk4-4nlGE2poXFU

# %%
# !git clone https://github.com/mubtasimahasan/disaster-image-classification-pytorch.git
# Out:
# Cloning into 'disaster-image-classification-pytorch'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 35 (delta 10), reused 34 (delta 9), pack-reused 0
# Unpacking objects: 100% (35/35), 10.02 KiB | 932.00 KiB/s, done.

# %%
# %pwd
# Out:
# '/kaggle/working'

# %%
# %cd /kaggle/working/disaster-image-classification-pytorch/
# %pwd
# %ls
# Out:
# /kaggle/working/disaster-image-classification-pytorch
# README.md  cli.py  configs/  data/  models/  utils/

# %%
import yaml

# Define the path to the config file
config_file_path = '/kaggle/working/disaster-image-classification-pytorch/configs/config.yaml'
# Open the config file for reading
with open(config_file_path, 'r') as file:
    config_data = yaml.safe_load(file)

# Update the values
config_data['debug'] = True # Remove this line for full run
config_data['path'] = "/kaggle/input/disaster/Comprehensive Disaster Dataset(CDD)"

# Write the updated data back to the file
with open(config_file_path, 'w') as file:
    yaml.dump(config_data, file)

# %%
# %run cli.py
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 140MB/s]
#  20%|██        | 1/5 [01:29<05:59, 89.91s/it]
# Epoch: 0 | Train loss: 0.985 | Train acc: 67.86 | Test loss: 0.788 | Test acc: 70.85
# Saving best model for epoch: 0
# ...
